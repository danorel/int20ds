# %%
import pandas as pd

# %%
orders_df = pd.read_csv("datasets/orders.csv")
nodes_df = pd.read_csv("datasets/nodes.csv")
geolocation_df = pd.read_csv("datasets/geolocation.csv")
weather_df = pd.read_json("datasets/weather.json")

# %% [markdown]
# ### Orders info

# %%
orders_df.shape
# Out:
# (5000, 5)

# %%
orders_df.dtypes
# Out:
# Id                     int64
# running_time          object
# completed_time        object
# route_distance_km    float64
# delta_time           float64
# dtype: object

# %%
orders_df.describe()
# Out:
#                  Id  route_distance_km   delta_time
# count  5.000000e+03        5000.000000  5000.000000
# mean   1.437166e+17           3.705945   613.161600
# std    5.322209e+18           1.767206   213.802608
# min   -9.220688e+18           0.000000    50.000000
# 25%   -4.422074e+18           2.359750   441.000000
# 50%    1.826612e+17           3.394000   614.000000
# 75%    4.817401e+18           4.753250   788.000000
# max    9.222287e+18          15.954000   999.000000

# %%
orders_df.head()
# Out:
#                     Id         running_time       completed_time  \
# 0 -4773019581999572651  2022-01-24 18:30:21  2022-01-24 18:44:43
# 1 -7575630690398473489  2022-01-24 06:53:53  2022-01-24 07:06:26
# 2 -6264582368520213833  2022-01-24 10:00:59  2022-01-24 10:15:58
# 3  5964315354301636538  2022-01-24 14:28:05  2022-01-24 14:35:08
# 4  1372379574816145639  2022-01-24 11:57:29  2022-01-24 12:06:29
#
#    route_distance_km  delta_time
# 0              3.740       862.0
# 1              3.526       753.0
# 2              5.071       899.0
# 3              2.867       423.0
# 4              3.751       540.0

# %% [markdown]
# ### Nodes info

# %%
nodes_df.shape
# Out:
# (480291, 5)

# %%
nodes_df.dtypes
# Out:
# Id               int64
# node_start       int64
# node_finish      int64
# distance       float64
# speed          float64
# dtype: object

# %%
nodes_df.describe()
# Out:
#                  Id    node_start   node_finish       distance          speed
# count  4.802910e+05  4.802910e+05  4.802910e+05  480291.000000  476307.000000
# mean   1.325593e+17  3.831874e+09  3.831719e+09      37.992984      31.293073
# std    5.329873e+18  2.702820e+09  2.702986e+09      43.718081      10.131391
# min   -9.221524e+18  1.098042e+07  1.098042e+07       0.076575       5.000000
# 25%   -4.399445e+18  1.570777e+09  1.570777e+09       9.548104      24.000000
# 50%    1.556848e+17  4.439628e+09  4.439628e+09      22.237880      30.000000
# 75%    4.817189e+18  5.214945e+09  5.215058e+09      50.181445      37.000000
# max    9.222287e+18  8.952487e+09  8.952487e+09    1374.510868     100.000000

# %%
nodes_df.head()
# Out:
#                     Id  node_start  node_finish    distance  speed
# 0 -2627062893189810184    10980432   2133368107   17.414917   32.0
# 1 -2627062893189810184    10980433   5212387954   17.186539   26.0
# 2 -2627062893189810184    10980445   5221700954   28.513481   26.0
# 3 -2627062893189810184    10980498     10980445  154.266122   25.0
# 4 -2627062893189810184    10980647   1986137911    8.542824   29.0

# %% [markdown]
# ### Weather info

# %%
weather_df.shape
# Out:
# (3, 1)

# %%
weather_df.head()
# Out:
#                                                            data
# nearest_area  [{'areaName': [{'value': 'Odessa'}], 'country'...
# request          [{'type': 'City', 'query': 'Odessa, Ukraine'}]
# weather       [{'date': '2022-01-24', 'astronomy': [{'sunris...

# %% [markdown]
# ### Geolocation

# %%
geolocation_df.head()
# Out:
#    Unnamed: 0                   Id  node_start  node_finish   distance  speed  \
# 0           0 -2627062893189810184    10980432   2133368107  17.414917   32.0
# 1           1 -6374252502568484586    10980432   2133368107  17.414917   25.0
# 2           2 -8332603950975862627    10980432   2133368107  17.414917   30.0
# 3           3  6728710084682273587    10980432   2133368107  17.414917   27.0
# 4           4  8390209597485549084    10980432   2133368107  17.415147   38.0
#
#    lon_start  lat_start                      tags_start    lon_end    lat_end  \
# 0  30.739248  46.472665  {'highway': 'traffic_signals'}  30.739022  46.472682
# 1  30.739248  46.472665  {'highway': 'traffic_signals'}  30.739022  46.472682
# 2  30.739248  46.472665  {'highway': 'traffic_signals'}  30.739022  46.472682
# 3  30.739248  46.472665  {'highway': 'traffic_signals'}  30.739022  46.472682
# 4  30.739248  46.472665  {'highway': 'traffic_signals'}  30.739022  46.472682
#
#                   tags_end
# 0  {'highway': 'crossing'}
# 1  {'highway': 'crossing'}
# 2  {'highway': 'crossing'}
# 3  {'highway': 'crossing'}
# 4  {'highway': 'crossing'}

# %%
geolocation_df = geolocation_df[["Id", "node_start", "node_finish", "lon_start", "lat_start", "lon_end", "lat_end"]]

# %%
geolocation_df.shape
# Out:
# (398688, 7)

# %%
geolocation_df.head()
# Out:
#                     Id  node_start  node_finish  lon_start  lat_start  \
# 0 -2627062893189810184    10980432   2133368107  30.739248  46.472665
# 1 -6374252502568484586    10980432   2133368107  30.739248  46.472665
# 2 -8332603950975862627    10980432   2133368107  30.739248  46.472665
# 3  6728710084682273587    10980432   2133368107  30.739248  46.472665
# 4  8390209597485549084    10980432   2133368107  30.739248  46.472665
#
#      lon_end    lat_end
# 0  30.739022  46.472682
# 1  30.739022  46.472682
# 2  30.739022  46.472682
# 3  30.739022  46.472682
# 4  30.739022  46.472682

# %% [markdown]
# ### Preprocessing
#
# 1. Finding average speed during the running time

# %%
speed_mean_df = nodes_df.groupby(["Id"], as_index=False).agg(**{"average_speed": ("speed", "mean")})

# %%
speed_mean_df.shape
# Out:
# (6000, 2)

# %% [markdown]
# ### Final info

# %%
df = orders_df \
    .merge(nodes_df, on='Id', how='inner') \
    .merge(speed_mean_df, on='Id', how='inner') \
    .merge(geolocation_df, left_on=['Id', 'node_start', 'node_finish'], right_on=["Id", 'node_start', 'node_finish'], how='left')

# %%
df.head(n=100)
# Out:
#                      Id         running_time       completed_time  \
# 0  -4773019581999572651  2022-01-24 18:30:21  2022-01-24 18:44:43
# 1  -4773019581999572651  2022-01-24 18:30:21  2022-01-24 18:44:43
# 2  -4773019581999572651  2022-01-24 18:30:21  2022-01-24 18:44:43
# 3  -4773019581999572651  2022-01-24 18:30:21  2022-01-24 18:44:43
# 4  -4773019581999572651  2022-01-24 18:30:21  2022-01-24 18:44:43
# ..                  ...                  ...                  ...
# 95 -4773019581999572651  2022-01-24 18:30:21  2022-01-24 18:44:43
# 96 -4773019581999572651  2022-01-24 18:30:21  2022-01-24 18:44:43
# 97 -4773019581999572651  2022-01-24 18:30:21  2022-01-24 18:44:43
# 98 -4773019581999572651  2022-01-24 18:30:21  2022-01-24 18:44:43
# 99 -4773019581999572651  2022-01-24 18:30:21  2022-01-24 18:44:43
#
#     route_distance_km  delta_time  node_start  node_finish   distance  speed  \
# 0                3.74       862.0    10980417   4768348185  31.771489   30.0
# 1                3.74       862.0    10980418   1570776947   3.673054   24.0
# 2                3.74       862.0    10980430   4768348188  15.550612   27.0
# 3                3.74       862.0    10980431   5125489557  50.034390   29.0
# 4                3.74       862.0    10980432   5213300015  13.453126   30.0
# ..                ...         ...         ...          ...        ...    ...
# 95               3.74       862.0  6583283285   4543514608  25.858234   28.0
# 96               3.74       862.0  6806370974   6806370970  24.456913   15.0
# 97               3.74       862.0  7825374441   1751477830  17.656921   43.0
# 98               3.74       862.0  7825374442   7825374441  19.745530   42.0
# 99               3.74       862.0  8018283981    290007862  13.355943   30.0
#
#     average_speed  lon_start  lat_start    lon_end    lat_end
# 0       29.537736  30.738275  46.468524  30.738097  46.468266
# 1       29.537736        NaN        NaN        NaN        NaN
# 2       29.537736        NaN        NaN        NaN        NaN
# 3       29.537736  30.739016  46.471232  30.738957  46.470784
# 4       29.537736  30.739248  46.472665  30.739226  46.472545
# ..            ...        ...        ...        ...        ...
# 95      29.537736  30.737318  46.467387  30.737209  46.467272
# 96      29.537736  30.732332  46.456489  30.732808  46.456384
# 97      29.537736  30.729736  46.459111  30.729650  46.458964
# 98      29.537736  30.729854  46.459263  30.729736  46.459111
# 99      29.537736  30.740571  46.482517  30.740747  46.482508
#
# [100 rows x 14 columns]

# %%
df.shape
# Out:
# (401311, 14)

# %%
df.to_csv("datasets/big-table.csv")
